# %% [markdown]
# # Quoridor Bot - Colab Setup (GitHub Workflow)
# This notebook uses GitHub to sync your codebase while using Google Drive exclusively to save large model checkpoints so they aren't lost between sessions.

# %%
# 1. Mount Google Drive (Only for saving models!)
from google.colab import drive
drive.mount('/content/drive')

# Create a dedicated models folder in your Drive if it doesn't exist
import os
os.makedirs('/content/drive/MyDrive/quoridor_models', exist_ok=True)
print("Drive mounted! Models will be saved to /content/drive/MyDrive/quoridor_models")

# %%
# 2. Clone or Update your GitHub Repository
import os
repo_url = 'https://github.com/YOUR_USERNAME/YOUR_REPO_NAME.git' # <-- REPLACE THIS!

if not os.path.exists('/content/quoridor'):
    # First time: Clone the repository
    # !git clone {repo_url} /content/quoridor
else:
    # Already cloned: Pull the latest offline changes
    # %cd /content/quoridor
    # !git pull origin main

# %cd /content/quoridor

# %%
# 3. Install dependencies from pyproject.toml
# !pip install -e .

# 4. Install Playwright for web automation
# !pip install playwright
# !playwright install chromium
# !playwright install-deps chromium

# %%
# 5. Run the Online Play Script
# !python code/play_online.py --config code/configs/settings.yaml
